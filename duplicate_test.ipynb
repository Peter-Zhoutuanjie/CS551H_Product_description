# %%
import pandas as pd

# %%
data = pd.read_csv('Women_Boohoo_UK_processed.csv',encoding='latin1')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9660 entries, 0 to 9659
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        9660 non-null   object
#  1   gender      9660 non-null   object
#  2   attributes  8144 non-null   object
#  3   colour      9660 non-null   object
#  4   price       9657 non-null   object
#  5   category    9659 non-null   object
#  6   desc        9658 non-null   object
# dtypes: object(7)
# memory usage: 528.4+ KB

# %%
data = data.drop_duplicates()
# Out:
#                                             name  gender  \
# 0                High Waisted Disco Denim Shorts  female
# 1            Black Crew Neck Basic Cotton Tshirt  female
# 2                    Faux Leather Trucker Jacket  female
# 3                         Cropped Slouchy Hoodie  female
# 4     Pinstripe Tie Waist Fitted Tailored Blazer  female
# ...                                          ...     ...
# 9655                    Cotton Plunge Maxi Dress  female
# 9656    Plus Satin Floral Drape Wrap Shirt Dress  female
# 9657           Plus Puff Sleeve Floral Sun Dress  female
# 9658       Boutique Lace Skater Bridesmaid Dress  female
# 9659            Oversized Dipped Hem Shirt Dress  female
#
#                                              attributes    colour    price  \
# 0     66% cotton, 24% polyester, 8% viscose, 2% elas...  mid wash  £12.00
# 1     100% COTTON. MACHINE WASHABLE. MODEL WEARS A U...     black   £6.00
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9660 entries, 0 to 9659
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        9660 non-null   object
#  1   gender      9660 non-null   object
#  2   attributes  8144 non-null   object
#  3   colour      9660 non-null   object
#  4   price       9657 non-null   object
#  5   category    9659 non-null   object
#  6   desc        9658 non-null   object
# dtypes: object(7)
# memory usage: 528.4+ KB
